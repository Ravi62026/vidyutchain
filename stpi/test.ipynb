# %%
import pandas as pd

# %%
df = pd.read_csv("meter_data_6months_20meters.csv")

# %%
df.head()
# Out:
#   meter_id            timestamp     voltage    current     power  \
# 0     M001  2006-12-16 17:15:00  234.366667  19.700000  4.587333
# 1     M001  2006-12-16 17:30:00  234.768667  17.773333  4.140667
# 2     M001  2006-12-16 17:45:00  234.630000  17.786667  4.159333
# 3     M001  2006-12-16 18:00:00  235.566000  17.706667  4.121067
# 4     M001  2006-12-16 18:15:00  234.803333  16.226667  3.768533
#
#    power_factor  consumption_kwh  is_anomaly anomaly_type day_of_week  ...  \
# 0          0.98         1.146833           0       NORMAL    Saturday  ...
# 1          0.98         1.035167           0       NORMAL    Saturday  ...
# 2          0.98         1.039833           0       NORMAL    Saturday  ...
# 3          0.98         1.030267           0       NORMAL    Saturday  ...
# 4          0.98         0.942133           0       NORMAL    Saturday  ...
#
#    house_type family_size work_schedule  solar_equipped daily_avg  \
# ...

# %%
df.anomaly_type
# Out:
# 0       NORMAL
# 1       NORMAL
# 2       NORMAL
# 3       NORMAL
# 4       NORMAL
#          ...
# 9995    NORMAL
# 9996    NORMAL
# 9997    NORMAL
# 9998    NORMAL
# 9999    NORMAL
# Name: anomaly_type, Length: 10000, dtype: str

# %%
df.columns
# Out:
# Index(['meter_id', 'timestamp', 'voltage', 'current', 'power', 'power_factor',
#        'consumption_kwh', 'is_anomaly', 'anomaly_type', 'day_of_week', 'hour',
#        'season', 'house_type', 'family_size', 'work_schedule',
#        'solar_equipped', 'daily_avg', 'daily_avg_consumption',
#        'hourly_avg_consumption', 'consumption_ratio', 'rolling_mean_24h',
#        'rolling_std_24h'],
#       dtype='str')

# %%
df.dtypes
# Out:
# meter_id                      str
# timestamp                     str
# voltage                   float64
# current                   float64
# power                     float64
# power_factor              float64
# consumption_kwh           float64
# is_anomaly                  int64
# anomaly_type                  str
# day_of_week                   str
# hour                        int64
# season                        str
# house_type                    str
# family_size                 int64
# work_schedule                 str
# solar_equipped               bool
# daily_avg                 float64
# daily_avg_consumption     float64
# hourly_avg_consumption    float64
# consumption_ratio         float64
# rolling_mean_24h          float64
# rolling_std_24h           float64
# dtype: object
